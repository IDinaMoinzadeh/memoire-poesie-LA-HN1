# %%
# %run nettoyer_index.py
# Out:
# [IGNORÉ] /home/dina/Documents/MEMOIRE CALCULS/poetes_LA.csv : fichier introuvable dans ce dossier
# [OK] /home/dina/Documents/MEMOIRE CALCULS/poetes_LA_canon_local_scored.csv : 622 → 618 poètes (4 retiré(s) : Clayton Eshleman, Diane Wakoski, Edward Field, Tara Betts)
# [OK] /home/dina/Documents/MEMOIRE CALCULS/poetes_LA_canon_national_SCORES_V2.csv : 618 poètes, aucun retrait nécessaire
# [IGNORÉ] /home/dina/Documents/MEMOIRE CALCULS/poetes_LA_avec_revues.csv : fichier introuvable dans ce dossier
# [OK] /home/dina/Documents/MEMOIRE CALCULS/poetes_LA_canon_local.csv : 622 → 618 poètes (4 retiré(s) : Clayton Eshleman, Diane Wakoski, Edward Field, Tara Betts)
# [OK] /home/dina/Documents/MEMOIRE CALCULS/poetes_LA_canon_national.csv : 622 → 618 poètes (4 retiré(s) : Clayton Eshleman, Diane Wakoski, Edward Field, Tara Betts)
# ...
